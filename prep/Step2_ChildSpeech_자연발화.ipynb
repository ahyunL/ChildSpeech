# %% [markdown]
# #Step2. 원본 데이터로만 학습 시 모델 성능 평가

# %% [markdown]
# ###1.환경 설정 (패키지 설치, 드라이브 마운트)
# 실험에 필요한 패키지 설치, 드라이브 마운트,
# 경로/나이대/랜덤시드(T4에서 재현 가능성 확보)설정

# %%
# !pip install transformers jiwer librosa soundfile accelerate pydub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 59.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
import glob
import random
import numpy as np
import pandas as pd
import torch

from jiwer import wer, cer

# 1) childrenvoice 루트 경로
ROOT_DIR  = "/content/drive/MyDrive/childrenvoice"
TRAIN_DIR = os.path.join(ROOT_DIR, "traindata")
VAL_DIR   = os.path.join(ROOT_DIR, "valdata")

# 실험 1에서 이미 생성했다고 가정하는 test CSV
TEST_CSV  = os.path.join(ROOT_DIR, "test_age4_12_per_age125_with_text.csv")

# 2) 사용할 나이대 (4~12세)
TARGET_AGES = list(range(4, 13))  # [4,5,6,7,8,9,10,11,12]

# 3) 랜덤 시드 고정 (재현성)
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# 4) 디바이스 정보 (코랩 T4)
device = "cuda" if torch.cuda.is_available() else "cpu"

print("ROOT_DIR :", ROOT_DIR)
print("TRAIN_DIR:", TRAIN_DIR)
print("VAL_DIR  :", VAL_DIR)
print("TEST_CSV :", TEST_CSV)
print("TARGET_AGES:", TARGET_AGES)
print("Device:", device)
# Out:
# ROOT_DIR : /content/drive/MyDrive/childrenvoice
# TRAIN_DIR: /content/drive/MyDrive/childrenvoice/traindata
# VAL_DIR  : /content/drive/MyDrive/childrenvoice/valdata
# TEST_CSV : /content/drive/MyDrive/childrenvoice/test_age4_12_per_age125_with_text.csv
# TARGET_AGES: [4, 5, 6, 7, 8, 9, 10, 11, 12]
# Device: cuda

# %% [markdown]
# ###2. train/val CSV 로드 (무결성 검증·텍스트 추출 완료본 사용)
#
# - 이전 Step에서 만든
#   - train_age4_12_all_with_text_cleaned.csv
#   - val_age4_12_per_age125_with_text_cleaned.csv
#   를 그대로 불러와 사용

# %%
import librosa

train_csv_path = "/content/drive/MyDrive/childrenvoice/train_age4_12_all_with_text_cleaned.csv"
val_csv_path   = "/content/drive/MyDrive/childrenvoice/val_age4_12_per_age125_with_text_cleaned.csv"

train_df = pd.read_csv(train_csv_path)
val_df   = pd.read_csv(val_csv_path)

print("train_df shape:", train_df.shape)
print("val_df   shape:", val_df.shape)
# Out:
# train_df shape: (9000, 5)
# val_df   shape: (1125, 5)

# %% [markdown]
# ###3. Dataset 클래스 정의 (원본 waveform 사용)
# - ChildSpeechDataset
#    - __getitem__에서
#      1. wav 로드 (16kHz)
#      2. WhisperProcessor로 log-mel 특징 추출
#      3. tokenizer로 텍스트 → 토큰
#    - trim/pad 사용하지 않음

# %%
from torch.utils.data import Dataset
from transformers import WhisperProcessor, WhisperForConditionalGeneration

class ChildSpeechDataset(Dataset):
    def __init__(self, df: pd.DataFrame, processor: WhisperProcessor, sampling_rate: int = 16000):
        self.df = df.reset_index(drop=True)
        self.processor = processor
        self.target_sr = sampling_rate

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        audio_path = row["audio_path"]
        text       = str(row["text"])

        # 1) 오디오 로드 (16kHz, 앞뒤 무음 제거 없음)
        audio, sr = librosa.load(audio_path, sr=self.target_sr)

        # 2) Whisper 입력 특징 (log-mel, 80-bin)
        inputs = self.processor(
            audio,
            sampling_rate=self.target_sr,
            return_tensors="pt",
        )
        input_features = inputs.input_features[0]  # [80, T]

        # 3) 레이블 토큰화
        labels = self.processor.tokenizer(
            text,
            return_tensors="pt",
        ).input_ids[0]

        return {
            "input_features": input_features,
            "labels": labels,
        }

# %% [markdown]
# ###4. DataCollator + Whisper-small 로드 + Dataset 준비
#
# - Whisper-small + Processor 로드
# - 언어/태스크 프롬프트만 설정 (ko, transcribe)
# - suppress_tokens / 후처리 사용 X
# - DataCollator에서 input_features stack, labels pad & -100 처리ㅁ

# %%
from dataclasses import dataclass
from typing import Dict, List

@dataclass
class DataCollatorWhisper:
    processor: WhisperProcessor

    def __call__(self, features: List[Dict]) -> Dict[str, torch.Tensor]:
        # input_features: [B, 80, T] 형태로 stack
        input_features = torch.stack([f["input_features"] for f in features])

        # labels: pad 후 pad_token_id -> -100
        label_features = [{"input_ids": f["labels"]} for f in features]
        labels_batch = self.processor.tokenizer.pad(
            label_features,
            padding=True,
            return_tensors="pt",
        )
        labels = labels_batch["input_ids"]
        labels[labels == self.processor.tokenizer.pad_token_id] = -100

        return {
            "input_features": input_features,
            "labels": labels,
        }

# Whisper-small + Processor 로드
MODEL_NAME = "openai/whisper-small"
LANG       = "ko"
TASK       = "transcribe"

processor = WhisperProcessor.from_pretrained(MODEL_NAME, language=LANG, task=TASK)
model     = WhisperForConditionalGeneration.from_pretrained(MODEL_NAME)

# 디코더 언어/태스크 프롬프트 고정 (한국어 + transcribe)
forced_ids = processor.get_decoder_prompt_ids(language=LANG, task=TASK)
model.config.forced_decoder_ids = forced_ids
if hasattr(model, "generation_config"):
    model.generation_config.forced_decoder_ids = forced_ids

# suppress_tokens / 후처리 사용 안 함
model.config.suppress_tokens = None
if hasattr(model, "generation_config"):
    model.generation_config.suppress_tokens = None

# (선택) 캐시 끄기
model.config.use_cache = False

model.to(device)

train_dataset = ChildSpeechDataset(train_df, processor, sampling_rate=16000)
val_dataset   = ChildSpeechDataset(val_df,   processor, sampling_rate=16000)

data_collator = DataCollatorWhisper(processor)

print("✅ train 샘플 수:", len(train_dataset))
print("✅ val 샘플 수  :", len(val_dataset))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# ✅ train 샘플 수: 9000
# ✅ val 샘플 수  : 1125

# %% [markdown]
# ###5. TrainingArguments (원본 waveform · 낮은 lr) + Trainer 정의 & 학습
#
# - lr: 3e-6 (기존 5e-6보다 더 보수적으로)
# - num_train_epochs: 5
# - early stopping: patience=2
# - trim/pad / suppress_tokens / temperature 조작 없음

# %%
import numpy as np
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback

# ➜ 1차 실험과 구분되는 새로운 출력 디렉터리
output_dir = os.path.join(ROOT_DIR, "models/whisper_small_childrenvoice_notrim_lr3e6")

# 혹시 모를 캐시 관련 이슈 방지
model.config.use_cache = False

training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=1,      # effective batch size = 4
    learning_rate=3e-6,                 # 더 낮은 학습률
    warmup_steps=200,
    num_train_epochs=5,                 # early stopping 있으니 5로 충분
    eval_strategy="epoch",              # epoch마다 평가
    save_strategy="epoch",              # epoch마다 체크포인트 저장
    logging_steps=50,
    predict_with_generate=True,
    generation_max_length=225,

    fp16=False,                         # 안정성 우선
    gradient_checkpointing=False,

    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    report_to=["tensorboard"],
    seed=SEED,
    data_seed=SEED,
)

def compute_metrics(eval_pred):
    preds, labels = eval_pred  # 둘 다 numpy array or 리스트

    # 1) 예측 토큰 → 문자열
    pred_str = processor.batch_decode(preds, skip_special_tokens=True)

    # 2) labels: -100 → pad_token_id로 치환 후 디코딩
    labels = np.where(labels != -100, labels, processor.tokenizer.pad_token_id)
    label_str = processor.tokenizer.batch_decode(labels, skip_special_tokens=True)

    return {
        "wer": wer(label_str, pred_str)
    }

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
    processing_class=processor,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,     # 2 epoch 연속 개선 없으면 정지
            early_stopping_threshold=1e-3,
        )
    ],
)

trainer.train()

# 🔹 저장 전에 GenerationConfig 정리 (sampling 파라미터 비우기)
gen_cfg = model.generation_config
if not gen_cfg.do_sample:
    # sampling 전용 파라미터는 greedy 모드에서 None으로 비워두는 게 안전
    if hasattr(gen_cfg, "temperature"):
        gen_cfg.temperature = None
    if hasattr(gen_cfg, "top_k"):
        gen_cfg.top_k = None
    if hasattr(gen_cfg, "top_p"):
        gen_cfg.top_p = None
    if hasattr(gen_cfg, "typical_p"):
        gen_cfg.typical_p = None

# 최종 모델 저장
trainer.save_model(output_dir)
processor.save_pretrained(output_dir)

print("✅ 파인튜닝 완료 및 모델/processor 저장:", output_dir)
# Out:
# You're using a WhisperTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='11250' max='11250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11250/11250 7:47:55, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.279200</td>
#       <td>0.346509</td>
#       <td>0.305195</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.124700</td>
#       <td>0.316934</td>
#       <td>0.275143</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.063500</td>
#       <td>0.310372</td>
#       <td>0.261703</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.032600</td>
#       <td>0.316926</td>
#       <td>0.261854</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.024700</td>
#       <td>0.321990</td>
#       <td>0.262760</td>
#     </tr>
#   </tbody>
# </table><p>
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3918: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 448, 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# ✅ 파인튜닝 완료 및 모델/processor 저장: /content/drive/MyDrive/childrenvoice/models/whisper_small_childrenvoice_notrim_lr3e6

# %% [markdown]
# ###6. 파인튜닝된 모델로 test 평가 (전체/나이별 WER, CER)
#
# - train/val과 동일하게 (원본 waveform → WhisperProcessor → generate)
# - 후처리 없이 raw 출력 기준으로 WER/CER 계산
# - 결과 CSV:
# whisper_small_finetuned3_age4_12_per_age125.csv

# %%
# 필요 시 재로드 (런타임이 끊겼다면 주석 해제)
model = WhisperForConditionalGeneration.from_pretrained(output_dir).to(device)
processor = WhisperProcessor.from_pretrained(output_dir)

# 언어 프롬프트 재설정 (suppress_tokens는 None 유지)
forced_ids = processor.get_decoder_prompt_ids(language=LANG, task=TASK)
model.config.forced_decoder_ids = forced_ids
if hasattr(model, "generation_config"):
    model.generation_config.forced_decoder_ids = forced_ids

model.config.suppress_tokens = None
if hasattr(model, "generation_config"):
    model.generation_config.suppress_tokens = None

model.to(device)

# 실험 1에서 만든 test 리스트 사용
test_df = pd.read_csv(TEST_CSV)
test_df = test_df[test_df["text"].astype(str).str.strip() != ""].reset_index(drop=True)
print("✅ test 샘플 수:", len(test_df))

pred_texts = []
ref_texts  = []
results    = []

for idx, row in test_df.iterrows():
    audio_path = row["audio_path"]
    ref_text   = str(row["text"]).strip()
    age        = row["age"]
    speaker_id = row["speaker_id"]
    utt_id     = row["utt_id"]

    # 1) 오디오 로드 (테스트도 원본 그대로, trim/pad 없음)
    audio, sr = librosa.load(audio_path, sr=16000)

    # 2) Whisper 입력 특징
    input_features = processor(
        audio,
        sampling_rate=16000,
        return_tensors="pt",
    ).input_features.to(device)

    # 3) 추론
    with torch.no_grad():
        predicted_ids = model.generate(input_features)

    # ✅ 평가용: 후처리 없이 raw 출력 사용
    raw_hyp_text = processor.batch_decode(
        predicted_ids,
        skip_special_tokens=True
    )[0].strip()

    ref_texts.append(ref_text)
    pred_texts.append(raw_hyp_text)

    results.append({
        "age": age,
        "speaker_id": speaker_id,
        "utt_id": utt_id,
        "audio_path": audio_path,
        "ref_text": ref_text,
        "hyp_text": raw_hyp_text,
    })

# 🔹 전체 WER / CER (raw 기준)
test_wer = wer(ref_texts, pred_texts)
test_cer = cer(ref_texts, pred_texts)

print("\n✅ 파인튜닝 Whisper-small 테스트 결과 (age 4~12, 각 나이 최대 125개, notrim & lr=3e-6)")
print(f"전체 WER: {test_wer:.4f}")
print(f"전체 CER: {test_cer:.4f}")

results_df = pd.DataFrame(results)

# 🔹 전체 결과 CSV (2차 실험용 새 파일명)
save_compare_path = os.path.join(
    ROOT_DIR,
    "whisper_small_finetuned3_age4_12_per_age125.csv"
)
results_df.to_csv(save_compare_path, index=False, encoding="utf-8-sig")
print("\n✅ 발화별 비교 결과 CSV 저장 완료:", save_compare_path)

# 🔹 나이별로 최대 20개씩 REF/HYP 출력 (raw 기준)
for age, sub in results_df.groupby("age"):
    sub = sub.sort_values(["speaker_id", "utt_id"]).reset_index(drop=True)

    print(f"\n==================== age {age} (n={len(sub)}) ====================")
    for i, r in sub.head(20).iterrows():
        print(f"[{i}] speaker={r['speaker_id']}, utt_id={r['utt_id']}")
        print(f"REF: {r['ref_text']}")
        print(f"HYP: {r['hyp_text']}")
        print("-" * 50)

# 🔹 나이별 WER/CER (raw 기준)
age_scores = []
for age, sub in results_df.groupby("age"):
    refs = sub["ref_text"].astype(str).tolist()
    hyps = sub["hyp_text"].astype(str).tolist()
    age_wer = wer(refs, hyps)
    age_cer = cer(refs, hyps)
    age_scores.append({
        "age": age,
        "wer": age_wer,
        "cer": age_cer,
        "n_samples": len(sub),
    })

age_scores_df = pd.DataFrame(age_scores).sort_values("age").reset_index(drop=True)
print("\n✅ 나이별 WER/CER:")
print(age_scores_df)
# Out:
# ✅ test 샘플 수: 1125
# `generation_config` default values have been modified to match model-specific defaults: {'temperature': None, 'begin_suppress_tokens': [220, 50257]}. If this is not desired, please set these values explicitly.
# A custom logits processor of type <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> has been passed to `.generate()`, but it was also created in `.generate()`, given its parameterization. The custom <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> will take precedence. Please check the docstring of <class 'transformers.generation.logits_process.SuppressTokensAtBeginLogitsProcessor'> to see related `.generate()` flags.
# ✅ 파인튜닝 Whisper-small 테스트 결과 (age 4~12, 각 나이 최대 125개, notrim & lr=3e-6)
# 전체 WER: 0.3373
# 전체 CER: 0.1896
#
# ✅ 발화별 비교 결과 CSV 저장 완료: /content/drive/MyDrive/childrenvoice/whisper_small_finetuned3_age4_12_per_age125.csv
#
# ==================== age 4 (n=125) ====================
# [0] speaker=1079, utt_id=K00011079-AFG10-L4N1D1-E-K0KK-00107381
# REF: 나쁜 먼지가 많아요.
# HYP: 나쁜 만지가 맞아요.
# --------------------------------------------------
# [1] speaker=1079, utt_id=K00021079-AFG10-L4N1D1-E-K0KK-00107404
# REF: 큰 소리로 말해요.
# HYP: 큰 소리로 말해요.
# --------------------------------------------------
# [2] speaker=1079, utt_id=K00031079-AFG10-L4N1D1-E-K0KK-00107429
# REF: 옷이 얼룩덜룩 더럽혀 있어요.
# HYP: 혹시 얼룩 얼룩 더럽혀 있어요?
# --------------------------------------------------
# [3] speaker=1079, utt_id=K00041079-AFG10-L4N1D1-E-K0KK-00107445
# REF: 책을 펴요.
# HYP: 차가 파요.
# --------------------------------------------------
# [4] speaker=1079, utt_id=K00051079-AFG10-L4N1D1-E-K0KK-00107462
# REF: 네모난 문을 열어요.
# HYP: 할머니는 뭘 알아요?
# --------------------------------------------------
# [5] speaker=1079, utt_id=K00061079-AFG10-L4N1D1-E-K0KK-00107481
# REF: 알아요.
# HYP: 알아요.
# --------------------------------------------------
# [6] speaker=1079, utt_id=K00071079-AFG10-L4N1D1-E-K0KK-00107523
# REF: 공책 두 권을 사요.
# HYP: 책총을 사요.
# --------------------------------------------------
# [7] speaker=1079, utt_id=K00081079-AFG10-L4N1D1-E-K0KK-01115850
# REF: 화가 났어요.
# HYP: 화가 났어요.
# --------------------------------------------------
# [8] speaker=1079, utt_id=K00091079-AFG10-L4N1D1-E-K0KK-00107575
# REF: 끝이 너무 울퉁불퉁해.
# HYP: 끝이 나면 불통불통해.
# --------------------------------------------------
# [9] speaker=1079, utt_id=K00101079-AFG10-L4N1D1-E-K0KK-00107601
# REF: 사탕.
# HYP: (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시) (잠시
# --------------------------------------------------
# [10] speaker=1079, utt_id=K00111079-AFG10-L4N1D1-E-K0KK-01328535
# REF: 벌레.
# HYP: 폴렉.
# --------------------------------------------------
# [11] speaker=1079, utt_id=K00121079-AFG10-L4N1D1-E-K0KK-00584090
# REF: 친구가 발을 굴러요.
# HYP: 신호가 발을 불러요.
# --------------------------------------------------
# [12] speaker=1079, utt_id=K00131079-AFG10-L4N1D1-E-K0KK-00108331
# REF: 마을이 없어요.
# HYP: 말이 없어요.
# --------------------------------------------------
# [13] speaker=1079, utt_id=K00141079-AFG10-L4N1D1-E-K0KK-00108365
# REF: 눈에는 눈물이 그렁그렁 맺혀 있어요.
# HYP: 나라는 목소리가 아무런 것들 있어요.
# --------------------------------------------------
# [14] speaker=1079, utt_id=K00151079-AFG10-L4N1D1-E-K0KK-00108383
# REF: 춤을 춰요.
# HYP: 재밌어요.
# --------------------------------------------------
# [15] speaker=1079, utt_id=K00161079-AFG10-L4N1D1-E-K0KK-01115862
# REF: 작은 민들레꽃이 예뻤어요.
# HYP: 작은 밀레렛 꽃이 예뻤어요.
# --------------------------------------------------
# [16] speaker=1079, utt_id=K00171079-AFG10-L4N1D1-E-K0KK-00108428
# REF: 손뼉을 쳤어요.
# HYP: 삼촌, 삼촌.
# --------------------------------------------------
# [17] speaker=1079, utt_id=K00181079-AFG10-L4N1D1-E-K0KK-00108446
# REF: 배가 기우뚱기우뚱 기울어요.
# HYP: 배가 쑥쑥 쑥쑥 쑥쑥 떠요.
# --------------------------------------------------
# [18] speaker=1079, utt_id=K00191079-AFG10-L4N1D1-E-K0KK-00108455
# REF: 여기서 내려요.
# HYP: 양시자 내려요.
# --------------------------------------------------
# [19] speaker=1079, utt_id=K00201079-AFG10-L4N1D1-E-K0KK-01115869
# REF: 오늘도 축구를 해요.
# HYP: 오늘도 축구를 해요.
# --------------------------------------------------
#
# ==================== age 5 (n=125) ====================
# [0] speaker=4858, utt_id=K00014858-AMG13-L5N1D1-E-K0KK-01946890
# REF: 왕께 인사를 했어요.
# HYP: 어쩌에 인사를 했어요?
# --------------------------------------------------
# [1] speaker=4858, utt_id=K00024858-AMG13-L5N1D1-E-K0KK-01946923
# REF: 섬세한 바이올린.
# HYP: 손주의한 다이올린.
# --------------------------------------------------
# [2] speaker=4858, utt_id=K00034858-AMG13-L5N1D1-E-K0KK-01946940
# REF: 깜깜한 밤은 무서워요.
# HYP: 깜깜한 밤은 무서워요.
# --------------------------------------------------
# [3] speaker=4858, utt_id=K00044858-AMG13-L5N1D1-E-K0KK-01946956
# REF: 치즈 케이크.
# HYP: 치즈 케이크.
# --------------------------------------------------
# [4] speaker=4858, utt_id=K00054858-AMG13-L5N1D1-E-K0KK-01946972
# REF: 무릎을 다쳤어요.
# HYP: 무릎을 바쳤어요.
# --------------------------------------------------
# [5] speaker=4858, utt_id=K00064858-AMG13-L5N1D1-E-K0KK-01946990
# REF: 샌드위치를 만들어요.
# HYP: 샌드위치를 만들어요.
# --------------------------------------------------
# [6] speaker=4858, utt_id=K00074858-AMG13-L5N1D1-E-K0KK-01947010
# REF: 병원에 가요.
# HYP: 병원에 가죠.
# --------------------------------------------------
# [7] speaker=4858, utt_id=K00084858-AMG13-L5N1D1-E-K0KK-01947022
# REF: 농부는 딸기를 따요.
# HYP: 동물은 딸기를 따요.
# --------------------------------------------------
# [8] speaker=4858, utt_id=K00094858-AMG13-L5N1D1-E-K0KK-01947044
# REF: 꽃의 이름은 무엇인가요?
# HYP: 꽃 이름은 무엇인가요?
# --------------------------------------------------
# [9] speaker=4858, utt_id=K00104858-AMG13-L5N1D1-E-K0KK-01947060
# REF: 물고기 두 마리가 있어요.
# HYP: 물고기 두 마리가 있어요.
# --------------------------------------------------
# [10] speaker=4858, utt_id=K00114858-AMG13-L5N1D1-E-K0KK-01947073
# REF: 색종이로 접어.
# HYP: 색종이로 젖어.
# --------------------------------------------------
# [11] speaker=4858, utt_id=K00124858-AMG13-L5N1D1-E-K0KK-01947093
# REF: 새로운 장화를 신었어요.
# HYP: 새로운 장화를 신었어요.
# --------------------------------------------------
# [12] speaker=4858, utt_id=K00134858-AMG13-L5N1D1-E-K0KK-01947110
# REF: 아내가 말했어요.
# HYP: 아내가 말했어요.
# --------------------------------------------------
# [13] speaker=4858, utt_id=K00144858-AMG13-L5N1D1-E-K0KK-01947120
# REF: 파란 하늘.
# HYP: 하란 하늘.
# --------------------------------------------------
# [14] speaker=4858, utt_id=K00154858-AMG13-L5N1D1-E-K0KK-01947132
# REF: 나비가 훨훨 춤췄어요.
# HYP: 나비가 활활 춤췄어요.
# --------------------------------------------------
# [15] speaker=4858, utt_id=K00164858-AMG13-L5N1D1-E-K0KK-01947142
# REF: 책 한 권 주세요!
# HYP: 색 한 건 주세요.
# --------------------------------------------------
# [16] speaker=4858, utt_id=K00174858-AMG13-L5N1D1-E-K0KK-01947158
# REF: 색종이 두 장을 빌립니다.
# HYP: 색종이 두 장을 밀립니다.
# --------------------------------------------------
# [17] speaker=4858, utt_id=K00184858-AMG13-L5N1D1-E-K0KK-01947168
# REF: 아기가 바닥을 깁니다.
# HYP: 아끼가 바당을 줍니다.
# --------------------------------------------------
# [18] speaker=4858, utt_id=K00194858-AMG13-L5N1D1-E-K0KK-01947185
# REF: 물속에서 참방참방 놀아요.
# HYP: 물똑에서 참방참방 놀아요.
# --------------------------------------------------
# [19] speaker=4858, utt_id=K00204858-AMG13-L5N1D1-E-K0KK-01947199
# REF: 짧은 바지.
# HYP: 짧은 바지.
# --------------------------------------------------
#
# ==================== age 6 (n=125) ====================
# [0] speaker=5206, utt_id=K00015206-AFG10-L2N1D4-E-K0KK-02154816
# REF: 왕께 인사했어요.
# HYP: 안 깨 인사했어요.
# --------------------------------------------------
# [1] speaker=5206, utt_id=K00025206-AFG10-L2N1D4-E-K0KK-02154837
# REF: 섬세한 바이올린.
# HYP: 선세한 바이올린.
# --------------------------------------------------
# [2] speaker=5206, utt_id=K00035206-AFG10-L2N1D4-E-K0KK-02154852
# REF: 깜깜한 밤은 무서워요.
# HYP: 깜깜한 밤은 무서워요.
# --------------------------------------------------
# [3] speaker=5206, utt_id=K00045206-AFG10-L2N1D4-E-K0KK-02154866
# REF: 치즈 케이크.
# HYP: 치즈 케이크.
# --------------------------------------------------
# [4] speaker=5206, utt_id=K00055206-AFG10-L2N1D4-E-K0KK-02154879
# REF: 무릎을 다쳤어요.
# HYP: 무릎을 다쳤어요.
# --------------------------------------------------
# [5] speaker=5206, utt_id=K00065206-AFG10-L2N1D4-E-K0KK-02154886
# REF: 샌드위치를 만들어요.
# HYP: 샌드위치를 만들어요.
# --------------------------------------------------
# [6] speaker=5206, utt_id=K00075206-AFG10-L2N1D4-E-K0KK-02154894
# REF: 병원에 가요.
# HYP: 변에 가요.
# --------------------------------------------------
# [7] speaker=5206, utt_id=K00085206-AFG10-L2N1D4-E-K0KK-02154906
# REF: 농부는 딸기를 따요.
# HYP: 농부는 딸기를 따요.
# --------------------------------------------------
# [8] speaker=5206, utt_id=K00095206-AFG10-L2N1D4-E-K0KK-02154945
# REF: 꽃의 이름은 무엇인가요?
# HYP: 꽃이 이름은 무엇인가요?
# --------------------------------------------------
# [9] speaker=5206, utt_id=K00105206-AFG10-L2N1D4-E-K0KK-02154967
# REF: 물고기 두 마리가 있어요.
# HYP: 물고기 두 마리가 있어요.
# --------------------------------------------------
# [10] speaker=5206, utt_id=K00115206-AFG10-L2N1D4-E-K0KK-02154975
# REF: 색종이로 접어.
# HYP: 셋종이로 접어.
# --------------------------------------------------
# [11] speaker=5206, utt_id=K00125206-AFG10-L2N1D4-E-K0KK-02154998
# REF: 새로운 장화를 신었어요.
# HYP: 새로운 장안을 식었어요.
# --------------------------------------------------
# [12] speaker=5206, utt_id=K00135206-AFG10-L2N1D4-E-K0KK-02155010
# REF: 아내가 말했어요.
# HYP: 아내가 말해 떠요.
# --------------------------------------------------
# [13] speaker=5206, utt_id=K00145206-AFG10-L2N1D4-E-K0KK-02155021
# REF: 파란 하늘.
# HYP: 파란 하늘.
# --------------------------------------------------
# [14] speaker=5206, utt_id=K00155206-AFG10-L2N1D4-E-K0KK-02155033
# REF: 나비가 훨훨 춤췄어요.
# HYP: 나비가 화요아 춤춘다.
# --------------------------------------------------
# [15] speaker=5206, utt_id=K00165206-AFG10-L2N1D4-E-K0KK-02155038
# REF: 책 한 권 주세요!
# HYP: 책 한 권 주세요.
# --------------------------------------------------
# [16] speaker=5206, utt_id=K00175206-AFG10-L2N1D4-E-K0KK-02155054
# REF: 색종이 두 장을 빌립니다.
# HYP: 세 종이 두 장을 빌립니다.
# --------------------------------------------------
# [17] speaker=5206, utt_id=K00185206-AFG10-L2N1D4-E-K0KK-02155068
# REF: 아기가 바닥을 깁니다.
# HYP: 아기가 바닥을 깁니다.
# --------------------------------------------------
# [18] speaker=5206, utt_id=K00195206-AFG10-L2N1D4-E-K0KK-02155076
# REF: 물속에서 참방참방 놀아요.
# HYP: 물속에서 천막천막 놀아요.
# --------------------------------------------------
# [19] speaker=5206, utt_id=K00205206-AFG10-L2N1D4-E-K0KK-02155079
# REF: 짧은 바지.
# HYP: 짧은 바지.
# --------------------------------------------------
#
# ==================== age 7 (n=125) ====================
# [0] speaker=6124, utt_id=K00016124-AMG20-L1N2D2-E-K0KK-02624358
# REF: 독립 운동을 하던 그는 아버지 손에 붙잡혀 끌려갔다.
# HYP: 독립 운동하던 그는 아버지 손에 붙잡혀 끌려갔다.
# --------------------------------------------------
# [1] speaker=6124, utt_id=K00026124-AMG20-L1N2D2-E-K0KK-02624362
# REF: 친구의 말에 공주가 놀라서 물었어요.
# HYP: 친구의 마을에 공주가 놀라서 물었어요.(물었어요)
# --------------------------------------------------
# [2] speaker=6124, utt_id=K00036124-AMG20-L1N2D2-E-K0KK-02624368
# REF: 옛날 어느 마을에 방귀를 자주 뀌는 형제가 살았어요.
# HYP: 옛날 어느 마을의 방귀를 자주 뀌는 형제가 살았어요.
# --------------------------------------------------
# [3] speaker=6124, utt_id=K00046124-AMG20-L1N2D2-E-K0KK-02624371
# REF: 동생이 나를 가자미눈으로 째려보고 있어요.
# HYP: 동생이 나를 가잠이 눈으로 쬐려 보고 있어요.
# --------------------------------------------------
# [4] speaker=6124, utt_id=K00056124-AMG20-L1N2D2-E-K0KK-02624379
# REF: 어느 마을에 나무꾼인 형과 농사꾼인 아우가 살고 있었어.
# HYP: 어느 말에 나무꾼 인형과 농사꾼 인아우가 살고 있었어.
# --------------------------------------------------
# [5] speaker=6124, utt_id=K00066124-AMG20-L1N2D2-E-K0KK-02624380
# REF: 절구통이 날아가 달나라에 쿵 떨어졌어.
# HYP: 절구통이 나라가 달나나에 궁 떨어졌어. 으쌍.
# --------------------------------------------------
# [6] speaker=6124, utt_id=K00076124-AMG20-L1N2D2-E-K0KK-02624381
# REF: 바람이 지나가는 소리가 들려요.
# HYP: 바람이 지나가는 소리가 들려요.
# --------------------------------------------------
# [7] speaker=6124, utt_id=K00086124-AMG20-L1N2D2-E-K0KK-02624382
# REF: 간호사 옷은 하얀색이에요
# HYP: 반우사 옷은 흰색이에요.
# --------------------------------------------------
# [8] speaker=6124, utt_id=K00096124-AMG20-L1N2D2-E-K0KK-02624383
# REF: 하지만 다들 귀찮은지 못들은 척 했어요.
# HYP: 하지만 다들 귀찮은 집 옷들은 적을 했어요.
# --------------------------------------------------
# [9] speaker=6124, utt_id=K00106124-AMG20-L1N2D2-E-K0KK-02624389
# REF: 할머니는 마른풀을 가져다가 소에게 주었어요.
# HYP: 할머니는 마른 풀을 가져다가 소에게 주었어요.
# --------------------------------------------------
# [10] speaker=6124, utt_id=K00116124-AMG20-L1N2D2-E-K0KK-02624395
# REF: 물이 몸을 흔들자, 불은 몽둥이에게 튀었지요.
# HYP: 물이 몸을 흔들자 불은 몸둥이에게 찌었뇨.
# --------------------------------------------------
# [11] speaker=6124, utt_id=K00126124-AMG20-L1N2D2-E-K0KK-02624401
# REF: 그제야 새끼 돼지는 집으로 들어갔답니다.
# HYP: 그제야 새끼 돼지는 집으로 들어갔답니다.
# --------------------------------------------------
# [12] speaker=6124, utt_id=K00136124-AMG20-L1N2D2-E-K0KK-02624405
# REF: 눈이 내리는 어느 겨울밤, 호랑이는 배가 고팠어요.
# HYP: 눈이 내리는 어느 겨울 밤 호랑이는 배가 고팠어요.
# --------------------------------------------------
# [13] speaker=6124, utt_id=K00146124-AMG20-L1N2D2-E-K0KK-02624421
# REF: 호랑이가 문으로 들어설 때였어요.
# HYP: 오랑이가 문으로 들어설 때였어요.
# --------------------------------------------------
# [14] speaker=6124, utt_id=K00156124-AMG20-L1N2D2-E-K0KK-02624429
# REF: 내가 온 걸 어떻게 알았지?
# HYP: 내가 웅그럽도 기억났지?
# --------------------------------------------------
# [15] speaker=6124, utt_id=K00166124-AMG20-L1N2D2-E-K0KK-02624440
# REF: 곶감은 나보다 무 엄청 무서운 놈인가 보네.
# HYP: 고까부 나부 엄청 무서웠어, 누누가 보네.
# --------------------------------------------------
# [16] speaker=6124, utt_id=K00176124-AMG20-L1N2D2-E-K0KK-02624452
# REF: 황소 아냐?
# HYP: 황사냥.
# --------------------------------------------------
# [17] speaker=6124, utt_id=K00186124-AMG20-L1N2D2-E-K0KK-02624460
# REF: 도둑은 호랑이인 줄 모르고 호랑이 등에 올라탔어요.
# HYP: 두둥은 호랑이인 줄 모르고 호랑이 등에 올라탔어요.
# --------------------------------------------------
# [18] speaker=6124, utt_id=K00196124-AMG20-L1N2D2-E-K0KK-02624469
# REF: 호랑이는 곶감이 탄 줄 알고 달리기 시작했지요.
# HYP: 호랑이는 꽃감이 텅쥐를 알고 달리기 시작했대요.
# --------------------------------------------------
# [19] speaker=6124, utt_id=K00206124-AMG20-L1N2D2-E-K0KK-02624481
# REF: 도둑은 호랑이 등 뒤에서 떨고 있었지요.
# HYP: 도둑은 호랑이 존 뒤에서 떨고 있었지요.
# --------------------------------------------------
#
# ==================== age 8 (n=125) ====================
# [0] speaker=7933, utt_id=K00017933-AMG20-L1N2D2-E-K0KK-03763264
# REF: 세 사람은 개미 한 마리도 놓치지 않고 모조리 붙잡았어요.
# HYP: 세 사람은 개미 한 마리도 놓치지 않고 모조리 붙잡았어요.
# --------------------------------------------------
# [1] speaker=7933, utt_id=K00027933-AMG20-L1N2D2-I-K0KK-03763394
# REF: 피노키오는 거센 물살에 휩쓸려 고래 뱃속으로 빨려 들어갔습니다.
# HYP: 피노키우는 더샌 물살에 휩쓸려 고래배 속으로 빨려들어갔습니다.
# --------------------------------------------------
# [2] speaker=7933, utt_id=K00037933-AMG20-L1N2D2-E-K0KK-03763345
# REF: 분노와 울부짖음이 뒤섞인 두 사람의 목소리가 들렸습니다.
# HYP: 전너와 물부지줌이 뒤섞인도 사람의 목소리가 찔렸습니다.
# --------------------------------------------------
# [3] speaker=7933, utt_id=K00047933-AMG20-L1N2D2-E-K0KK-03763421
# REF: 게다가 마스크까지 가지고 그렇게 하다니 말이야.
# HYP: 게다가 마스크까지 가지고 그렇게 하다니 말이야.
# --------------------------------------------------
# [4] speaker=7933, utt_id=K00057933-AMG20-L1N2D2-E-K0KK-03763443
# REF: 각 학교에 감사를 거듭 드립니다.
# HYP: 갑, 학교에 감사를 거듭 드립니다.
# --------------------------------------------------
# [5] speaker=7933, utt_id=K00067933-AMG20-L1N2D2-E-K0KK-03763473
# REF: 검은 동그라미는 해적들이 죽이겠다고 협박하는 신호였거든.
# HYP: 까문 동그라미는 쇠젅들이 죽이겠다고 협박가는 신호였거든요.
# --------------------------------------------------
# [6] speaker=7933, utt_id=K00077933-AMG20-L1N2D2-I-K0KK-03763512
# REF: 또, 원래 주인공의 이름은 삼보였어.
# HYP: 또, 원래 주인공을 이름은 삼보였어.
# --------------------------------------------------
# [7] speaker=7933, utt_id=K00087933-AMG20-L1N2D2-E-K0KK-03763534
# REF: 내가 혼난 건 다 내가 잘못했기 때문이지.
# HYP: 내가 혼난 건 다 내가 잘못했기 때문이지.
# --------------------------------------------------
# [8] speaker=7933, utt_id=K00097933-AMG20-L1N2D2-E-K0KK-03763559
# REF: 내리 쪼이는 햇볕은 나날이 뜨거워졌습니다.
# HYP: 내리쪼이는 햇볕은 나날이 뜨거워졌습니다.
# --------------------------------------------------
# [9] speaker=7933, utt_id=K00107933-AMG20-L1N2D2-E-K0KK-03763620
# REF: 그가 악의가 가득한 웃음을 지으며 말했다.
# HYP: 그가 악의가 가득한 웃음을 찌며 말했다.
# --------------------------------------------------
# [10] speaker=7933, utt_id=K00117933-AMG20-L1N2D2-I-K0KK-03763665
# REF: 가게 주인은 알료샤의 아버지에게 월급을 주었습니다.
# HYP: 가게 주인은 알료사를 아버지에게 월급을 추었습니다.
# --------------------------------------------------
# [11] speaker=7933, utt_id=K00127933-AMG20-L1N2D2-E-K0KK-03763688
# REF: 그는 아이들이 조용해지기를 바랄 뿐이지요.
# HYP: 그는 아이들이 조용해지기를 바를 뿐이지요.
# --------------------------------------------------
# [12] speaker=7933, utt_id=K00137933-AMG20-L1N2D2-E-K0KK-03763716
# REF: 그의 대답은 듣지 않고 다 안다는 듯 앞장을 섰다.
# HYP: 그의 대답은 듣지 않고 다 안다는 듯 앞장을 섰다.
# --------------------------------------------------
# [13] speaker=7933, utt_id=K00147933-AMG20-L1N2D2-E-K0KK-03763737
# REF: 어쨌든 토끼와 고슴도치의 시합은 공정하지 못했어요.
# HYP: 어쨌든 토끼와 고삼도치의 시합은 공정하지 못했어요.
# --------------------------------------------------
# [14] speaker=7933, utt_id=K00157933-AMG20-L1N2D2-E-K0KK-03763795
# REF: 오 파운드가 있다면 전 수선화에 걸 거에요.
# HYP: 옥 파운드가 있다면 전 소선화에 걸 거예요.
# --------------------------------------------------
# [15] speaker=7933, utt_id=K00167933-AMG20-L1N2D2-E-K0KK-03763850
# REF: 붉은 석류꽃도 보았지요.
# HYP: 북은 성류꽃도 고맙지요.
# --------------------------------------------------
# [16] speaker=7933, utt_id=K00177933-AMG20-L1N2D2-I-K0KK-03763870
# REF: 이반은 섬뜩한 느낌을 받았습니다.
# HYP: 이반은 섬뜩한 느낌을 받았습니다.
# --------------------------------------------------
# [17] speaker=7933, utt_id=K00187933-AMG20-L1N2D2-E-K0KK-03763924
# REF: 그는 항상 쥣빛의 작은 눈을 가늘게 떴어요.
# HYP: 그는 항상 쥐빛의 작은 눈을 가늑에 떴어요.
# --------------------------------------------------
# [18] speaker=7933, utt_id=K00197933-AMG20-L1N2D2-E-K0KK-03763957
# REF: 종이 끝에 실을 꿰어서 나뭇가지에 드문드문 매어 답니다.
# HYP: 종이 끝에 실을 꾀어서 나뭇가지에 주무원 주문 매워답니다.
# --------------------------------------------------
# [19] speaker=7933, utt_id=K00207933-AMG20-L1N2D2-E-K0KK-03763975
# REF: 그리고 두 손을 가슴 위에 모아 얹고 헤엄쳤습니다.
# HYP: 그리고 주손을 가슴 위에 모아 웃고 헤엄쳤습니다.
# --------------------------------------------------
#
# ==================== age 9 (n=125) ====================
# [0] speaker=7894, utt_id=K01017894-AMG20-L4N1D1-E-K0KK-03858064
# REF: 이 섬에도 못된 여우 세 마리가 살거든.
# HYP: 이섬에도 못된 여우 세 마리가 살거든.
# --------------------------------------------------
# [1] speaker=7894, utt_id=K01107894-AMG20-L4N1D1-E-K0KK-03858362
# REF: 저와 결혼해 주세요.
# HYP: 저와 결혼해 주세요.
# --------------------------------------------------
# [2] speaker=7894, utt_id=K01117894-AMG20-L4N1D1-E-K0KK-03858394
# REF: 누가 내 의자도 다 부서트려 놓았어요.
# HYP: 누가 내 의자도 다 부서트려 놓았어요.
# --------------------------------------------------
# [3] speaker=7894, utt_id=K01127894-AMG20-L4N1D1-E-K0KK-03858411
# REF: 벌써 가을이 되었어요.
# HYP: 벌써 가을이 되었어요.
# --------------------------------------------------
# [4] speaker=7894, utt_id=K01177894-AMG20-L4N1D1-E-K0KK-03858536
# REF: 당나귀는 목을 길게 빼고 말했습니다.
# HYP: 당나귀는 목을 길게 빼고 말했습니다.
# --------------------------------------------------
# [5] speaker=7894, utt_id=K01217894-AMG20-L4N1D1-E-K0KK-03858646
# REF: 팥죽을 먹으면서 좀 쉬어요.
# HYP: 파죽을 먹으면서 줄 셔요.
# --------------------------------------------------
# [6] speaker=7894, utt_id=K01267894-AMG20-L4N1D1-E-K0KK-03858833
# REF: 더 이상 못 가겠어.
# HYP: 더 이상 못 가겠어.
# --------------------------------------------------
# [7] speaker=7894, utt_id=K01317894-AMG20-L4N1D1-E-K0KK-03858962
# REF: 그래, 궁궐로 한번 데리고 와 봐라.
# HYP: 그래, 궁궐로 한번 데리고 와.
# --------------------------------------------------
# [8] speaker=7894, utt_id=K01347894-AMG20-L4N1D1-E-K0KK-03859061
# REF: 젊은 여인은 덴마크에서 왔다고 말했습니다.
# HYP: 젊은 여인은 갯마크에서 왔다고 말했습니다.
# --------------------------------------------------
# [9] speaker=7894, utt_id=K01397894-AMG20-L4N1D1-E-K0KK-03859194
# REF: 왕의 피부는 어린아이처럼 매끈거렸다.
# HYP: 언니, 비둔어 오리 나리 좁은 내껑거렸다.
# --------------------------------------------------
# [10] speaker=7894, utt_id=K01437894-AMG20-L4N1D1-E-K0KK-03859360
# REF: 그리고 나서 초콜릿을 집어 맛있게 먹었다.
# HYP: 그리고 나서 초콜릿을 집어 맛있게 먹었다.
# --------------------------------------------------
# [11] speaker=7894, utt_id=K01527894-AMG20-L4N1D1-E-K0KK-03859666
# REF: 방망이질 소리가 멀리 울려 들렸다.
# HYP: 박마영이지의 소리가 멀리 울려 들렸다.
# --------------------------------------------------
# [12] speaker=7894, utt_id=K01577894-AMG20-L4N1D1-E-K0KK-03993202
# REF: 출입구를 좁혀라.
# HYP: 주리꾸를 쪼그럼.
# --------------------------------------------------
# [13] speaker=7894, utt_id=K01587894-AMG20-L4N1D1-E-K0KK-03993294
# REF: 잘못된 일은 하면 안 돼.
# HYP: 잘못된 일을 하면 안 돼.
# --------------------------------------------------
# [14] speaker=7894, utt_id=K01597894-AMG20-L4N1D1-E-K0KK-03993322
# REF: 어서 먹을 것을 더 내놓아라.
# HYP: 어서 먹을 것을 터뜨려놓아라. 네.
# --------------------------------------------------
# [15] speaker=7894, utt_id=K01607894-AMG20-L4N1D1-E-K0KK-03993343
# REF: 이 오리는 전혀 다르게 생겼네.
# HYP: 이 오리를 전혀 다르게 생각네. 응?
# --------------------------------------------------
# [16] speaker=7894, utt_id=K01617894-AMG20-L4N1D1-E-K0KK-03993368
# REF: 기뻐서 눈물이 글썽글썽했습니다.
# HYP: 기분에서 눈물이 글썽글썽했습니다.
# --------------------------------------------------
# [17] speaker=7894, utt_id=K01627894-AMG20-L4N1D1-E-K0KK-03993408
# REF: 가서 내가 응원을 오라 했다고 전해라.
# HYP: 가서 내가 응원을 오고라 했다고 전해라!
# --------------------------------------------------
# [18] speaker=7894, utt_id=K01637894-AMG20-L4N1D1-I-K0KK-03993430
# REF: 윌리엄이 나를 놀렸어요.
# HYP: 윌리엄이 나를 놀렸어요.
# --------------------------------------------------
# [19] speaker=7894, utt_id=K01647894-AMG20-L4N1D1-E-K0KK-03993447
# REF: 이게 어찌 된 일일까?
# HYP: 이게 어찌된일까?
# --------------------------------------------------
#
# ==================== age 10 (n=125) ====================
# [0] speaker=6152, utt_id=K00016152-AMG30-L2N1D1-E-K0KK-02635887
# REF: 어찌나 크게 만들었는지, 상류계급이 신고 다니는 신발은 유사시에 바구니로 써도 될 정도였습니다.
# HYP: 어찌나 크게 만들었는지 성료기꾸비 친구 다니는 신발은 무산시에 바쁜 것도 써볼텐데요, 좋습니다.
# --------------------------------------------------
# [1] speaker=6152, utt_id=K00026152-AMG30-L2N1D1-E-K0KK-02635944
# REF: 언덕 위 커다란 나무가 왠지 그들이 떠나온 마을의 나무와 너무나 닮아 있었다.
# HYP: 엄마, 이 크더란 남과 온기 크더리 사는 나무와 농락들만 있었다.
# --------------------------------------------------
# [2] speaker=6152, utt_id=K00036152-AMG30-L2N1D1-E-K0KK-02635983
# REF: 엄청 힘들게 열었는데 마지막 상자에서 나온 거라곤 겨우 흰 종이 뿐이라니.
# HYP: 공사 신비님이 말하는데, 마지막 소녀에서 나온 거라고 저흥종일 꿈이라니.
# --------------------------------------------------
# [3] speaker=6152, utt_id=K00046152-AMG30-L2N1D1-I-K0KK-02636040
# REF: 에르나는 그가 하려는 얘기가 시엘의 인생이라는 것을 알자 호기심이 생겼다.
# HYP: 옛날에는 누가 하려는 얘기가 역시 일을 인증이라는 것을 알자 흥미밀이 생겼다.
# --------------------------------------------------
# [4] speaker=6152, utt_id=K00056152-AMG30-L2N1D1-I-K0KK-02636092
# REF: 여자는 사진작가로 활동하며 빅토리아 여왕 등 여러 명사의 모습을 사진으로 기록하기도 했어요.
# HYP: 여자는 사진작가로 활동하며, 빅토리아 여왕 등 여러 명사의 모습을 사진으로 기록하기도 했어요.
# --------------------------------------------------
# [5] speaker=6152, utt_id=K00066152-AMG30-L2N1D1-E-K0KK-02636119
# REF: 연고를 포함해서 땅콩으로 만들지 못할 것이 없을 정도였지요.
# HYP: 연구를 포함해서 땅콩으로 만드지 못할 곳이 없을 정도였지요.
# --------------------------------------------------
# [6] speaker=6152, utt_id=K00076152-AMG30-L2N1D1-E-K0KK-02636167
# REF: 불꽃들은 멋진 황금 꽃들처럼 하늘을 향해 높이 치솟으며 모두 불꽃을 활짝 피웠다.
# HYP: 불꽃들은 멋진 흙운 불꽃처럼 하늘을 향해 높이 치솟으며 모두 불꽃을 살짝 키웠다.
# --------------------------------------------------
# [7] speaker=6152, utt_id=K00086152-AMG30-L2N1D1-E-K0KK-02636224
# REF: 열심히 나무를 하던 아들은 점심을 먹고 쉬는 시간에 새 둥지를 찾아 나섰습니다.
# HYP: 몇십이 나무를 하던 아들은 점심을 먹고 쉬는 시간에 새 둔지를 찾아 나섰습니다.
# --------------------------------------------------
# [8] speaker=6152, utt_id=K00096152-AMG30-L2N1D1-E-K0KK-02636314
# REF: 예덕 상무사는 예전부터 예산과 덕산의 보부상을 관리하는 정부 관서다.
# HYP: 예득한 부산은 옛전부터 예산과 독단에 고부상을 관리하는 정부 관서다.
# --------------------------------------------------
# [9] speaker=6152, utt_id=K00106152-AMG30-L2N1D1-E-K0KK-02636359
# REF: 오늘 낮에는 당신이 할 일이 없지만 밤에는 아버지께서 세 가지 이야기를 하라고 하실 거예요.
# HYP: 오늘 낮에는 당신이 할 일이 없지만 밤에는 아버지로 세 가지 이야기를 하라고 하실 거예요.
# --------------------------------------------------
# [10] speaker=6152, utt_id=K00116152-AMG30-L2N1D1-E-K0KK-02636418
# REF: 오늘은 두 마리의 늙은 참새와 한 마리의 젊은 참새가 왼쪽발로 땅을 긁는 것이 아닙니까?
# HYP: 오늘은 두 마리의 늙은 참새와 한 마리의 젊은 참새가 왼쪽 발로 땅을 굴놨이 아닙니까.
# --------------------------------------------------
# [11] speaker=6152, utt_id=K00126152-AMG30-L2N1D1-E-K0KK-02636518
# REF: 오목한 수정 유리 벽이 푸른 원을 그리며 돌자 반사광이 발산했습니다.
# HYP: 오목한 후정우리베니 손원을 그리며 돌자 반사광이 발살했습니다.
# --------------------------------------------------
# [12] speaker=6152, utt_id=K00136152-AMG30-L2N1D1-I-K0KK-02636543
# REF: 올렌카는 사람들에게 학교 이야기와 교과 내용에 대해 말하며 자못 심각해했습니다.
# HYP: 몰랭카는 사람들에게 학교 이야기와 교과 내용에 대화라면 조긋게 했습니다.
# --------------------------------------------------
# [13] speaker=6152, utt_id=K00146152-AMG30-L2N1D1-E-K0KK-02636595
# REF: 완고한 아버지가 걱정스러워 급히 찾아가던 때였네.
# HYP: 완부한 아버지가 좀스러워 급히 찾아가 좀 떼었네.
# --------------------------------------------------
# [14] speaker=6152, utt_id=K00156152-AMG30-L2N1D1-E-K0KK-02636636
# REF: 왕께서 내일 하루 동안 성당을 지으라고 하시는데 완성하지 못하면 큰 벌을 내리겠다고 하셨습니다.
# HYP: 왕께서 내일 하루 동안 성당을 지으라고 하시는데, 완성하지 못하면 큰 벌을 내리겠다고 했습니다.안녕하세요.
# --------------------------------------------------
# [15] speaker=6152, utt_id=K00166152-AMG30-L2N1D1-E-K0KK-02636692
# REF: 왕비는 세 왕자에 대해 끊임없이 물어보며 왜 자신에게 세 왕자를 숨겼냐고 따졌다.
# HYP: 왕비는 쇠왕자에 대해 끊임없이 물어 문역을 자신에게 쇠왕자를 챙겨 주라고 따졌다.
# --------------------------------------------------
# [16] speaker=6152, utt_id=K00176152-AMG30-L2N1D1-E-K0KK-02636806
# REF: 왕비는 오랫동안 밤을 지새워야 했고 유모는 앞으로 일어날 일에 대해 마음이 편안해졌다.
# HYP: 랑비는 오랫동안 밤을 지셔야 했고, 유오는 앞으로 일어날 일에 대한 마음이 편안해졌다.
# --------------------------------------------------
# [17] speaker=6152, utt_id=K00186152-AMG30-L2N1D1-E-K0KK-02636982
# REF: 왕은 사랑하는 여인과의 결혼을 막는 가톨릭교의 교황에게서 벗어나고자 나라의 종교까지 바꾸었답니다.
# HYP: 그러나는 사랑하는 여인과의 결혼을 막는 카토리퀴즈 왕에서 벗어나고자 나라의 종교까지 바꾸었답니다.
# --------------------------------------------------
# [18] speaker=6152, utt_id=K00196152-AMG30-L2N1D1-E-K0KK-02637101
# REF: 왜 우리는 저녁 내내 발코니에서 형언할 수 없는 침묵을 지킨 채 거지같은 음유시인의 노래를 들었는가?
# HYP: 왜 우리는 저녁 내내 발코니에서 형원할 수 없는 침묵을 시킨 채 거지같은 읍는 시인의 노래를 들었는가?
# --------------------------------------------------
# [19] speaker=6152, utt_id=K00206152-AMG30-L2N1D1-E-K0KK-02637134
# REF: 작은 요정이 복숭아 뒤에 숨어서 방글방글 웃고 있습니다.
# HYP: 작은 요정이 북중화 뒤에 숨어서 방글방글 웃고 있습니다.
# --------------------------------------------------
#
# ==================== age 11 (n=125) ====================
# [0] speaker=8573, utt_id=K00018573-AFG30-L1N2D1-E-K0KK-04204543
# REF: 어찌나 크게 만들었는지, 상류계급이 신고 다니는 신발은 유사시에 바구니로 써도 될 정도였습니다.
# HYP: 어찌나 크게 만들었는지 상류 계급이 신고 다니는 신발은 유사시의 바구니로 써도 될 정도였습니다.
# --------------------------------------------------
# [1] speaker=8573, utt_id=K00038573-AFG30-L1N2D1-E-K0KK-04204980
# REF: 엄청 힘들게 열었는데 마지막 상자에서 나온 거라곤 겨우 흰 종이 뿐이라니.
# HYP: 엄청 힘들게 열었는데, 마지막 상자에서 나온 거라곤 겨우 흰 종이 뿐이라니.
# --------------------------------------------------
# [2] speaker=8573, utt_id=K00088573-AFG30-L1N2D1-E-K0KK-04205856
# REF: 열심히 나무를 하던 아들은 점심을 먹고 쉬는 시간에 새 둥지를 찾아 나섰습니다.
# HYP: 열심히 나무를 하던 아들은 점심을 먹고 쉬는 시간에 새 동지를 찾아다섰습니다.
# --------------------------------------------------
# [3] speaker=8573, utt_id=K00098573-AFG30-L1N2D1-E-K0KK-04281804
# REF: 예덕 상무사는 예전부터 예산과 덕산의 보부상을 관리하는 정부 관서다.
# HYP: 예덕 상무산은 예전부터 예상과 덕산의 보부상을 관리하는 정부 관서다.
# --------------------------------------------------
# [4] speaker=8573, utt_id=K00128573-AFG30-L1N2D1-E-K0KK-04282011
# REF: 오목한 수정 유리 벽이 푸른 원을 그리며 돌자 반사광이 발산했습니다.
# HYP: 오목한 수정유리 벽이 푸른 원을 그리며 돌자 반사광이 발산했습니다.
# --------------------------------------------------
# [5] speaker=8573, utt_id=K00138573-AFG30-L1N2D1-I-K0KK-04206595
# REF: 올렌카는 사람들에게 학교 이야기와 교과 내용에 대해 말하여 자못 심각해했습니다.
# HYP: 올렌카는 사람들에게 학교이야기와 교과 내용에 대해 말하여 잠옷 심각해했습니다.
# --------------------------------------------------
# [6] speaker=8573, utt_id=K00148573-AFG30-L1N2D1-E-K0KK-04282044
# REF: 완고한 아버지가 걱정스러워 급히 찾아가던 때였네.
# HYP: 왕구한 아버지가 걱정스러워 급히 찾아갔던 때였네.
# --------------------------------------------------
# [7] speaker=8573, utt_id=K00168573-AFG30-L1N2D1-E-K0KK-04282217
# REF: 왕비는 세 왕자에 대해 끊임없이 물어보며 왜 자신에게 세 왕자를 숨겼냐고 따졌다.
# HYP: 왕비는 새 왕자에 대해 끊임없이 물어보며 왜 자신에게 새 왕자를 숨겼냐고 따졌다.
# --------------------------------------------------
# [8] speaker=8573, utt_id=K00178573-AFG30-L1N2D1-E-K0KK-04207133
# REF: 왕비는 오랫동안 밤을 지새워야 했고 유모는 앞으로 일어날 일에 대해 마음이 편안해졌다.
# HYP: 왕비는 오랫동안 밤을 지세워야 했고 유모는 앞으로 일어날 일에 대해 마음이 편안해졌다.
# --------------------------------------------------
# [9] speaker=8573, utt_id=K00188573-AFG30-L1N2D1-E-K0KK-04282245
# REF: 왕은 사랑하는 여인과의 결혼을 막는 가톨릭교의 교황에게서 벗어나고자 나라의 종교까지 바꾸었답니다.
# HYP: 왕은 사랑하는 여인과의 결혼을 막는 가톨릭교의 교황에서 벗어나고자 나라의 종교까지 바꾸었답니다.
# --------------------------------------------------
# [10] speaker=8573, utt_id=K00208573-AFG30-L1N2D1-E-K0KK-04280684
# REF: 작은 요정이 복숭아 뒤에 숨어서 방글방글 웃고 있습니다.
# HYP: 작은 요정이 복숭아 뒤에 숨어서 방글방글 웃고 있습니다.
# --------------------------------------------------
# [11] speaker=8573, utt_id=K00218573-AFG30-L1N2D1-I-K0KK-04281080
# REF: 유럽의 다른 나라에서도 그림을 그려 달라는 요청이 와서 루벤스는 각지를 돌아다니기도 했어요.
# HYP: 유럽의 다른 나라에서도 그림을 그려 달라는 요청이 와서 로벤스는 각질을 돌아다니기도 했어요.
# --------------------------------------------------
# [12] speaker=8573, utt_id=K00228573-AFG30-L1N2D1-E-K0KK-04281569
# REF: 윷놀이는 윷을 땅에다 던지며 노는 놀이이다.
# HYP: 윷놀이는 육을 땅에다 던지며 노는 놀이이다.
# --------------------------------------------------
# [13] speaker=8573, utt_id=K00248573-AFG30-L1N2D1-E-K0KK-04282568
# REF: 의연하게 세상을 사는 사람은 자신의 얼굴과 허름한 옷을 결코 부끄럽게 여기지 않는단다.
# HYP: 의연하게 세상을 사는 사람은 자신의 얼굴과 호르만 옷을 결코 부끄럽게 여기지 않는단다.
# --------------------------------------------------
# [14] speaker=8573, utt_id=K00278573-AFG30-L1N2D1-E-K0KK-04284969
# REF: 이 박물관은 나주 배의 우수한 품질을 국내외에 널리 알리기 위해 세워졌어요.
# HYP: 이 박물관은 나주배의 우수한 품질을 국내외에 널리 알리기 위해 세워뒀어요.
# --------------------------------------------------
# [15] speaker=8573, utt_id=K00318573-AFG30-L1N2D1-E-K0KK-04285377
# REF: 이곳에는 이륜 마차, 덮개가 있는 마차, 합승 마차 등 다양한 마차들이 홍수처럼 넘치고 있었습니다.
# HYP: 이곳에는 이른마차, 법계가 있는 마차, 합숙마차 등 다양한 마차들이 홍수처럼 넘치고 있었습니다.
# --------------------------------------------------
# [16] speaker=8573, utt_id=K00328573-AFG30-L1N2D4-E-K0KK-04370199
# REF: 이곳은 "톰소여의 모험", "허클베리 핀의 모험", "미시시피강의 추억", "톰소여 탐정이 되다"의 배경이 되기도 했다.
# HYP: 이곳은 통소여의 모험, 허클베리 핀의 모험, 이씨시 피강의 추억, 통소여 탐장이 되다에 배경이 되기도 했다.
# --------------------------------------------------
# [17] speaker=8573, utt_id=K00338573-AFG30-L1N2D1-E-K0KK-04285683
# REF: 이곳은 프랑스 남부의 르와르 강 상류에 있는 마을로 밭도 얼마 없는 곳이었어요.
# HYP: 이곳은 프랑스 남부의 루아르강 창류에 있는 마을로 밭도 얼마 없는 곳이었어요.
# --------------------------------------------------
# [18] speaker=8573, utt_id=K00348573-AFG30-L1N2D1-E-K0KK-04285786
# REF: 이 세상을 만든 창조주의 지혜는 영원한 법이다.
# HYP: 이 세상을 만든 상조주의 지혜는 영원한 법이다.
# --------------------------------------------------
# [19] speaker=8573, utt_id=K00358573-AFG30-L1N2D1-E-K0KK-04286684
# REF: 이런 것은 장난감보다 더 값어치가 없는 물건이기 때문에 명작이고 아니고를 말할 게 아니다.
# HYP: 이런 것은 장난감보다 더 가보치가 있는 물건이기 때문에 명작이고 아니구를 말할 게 아니다.
# --------------------------------------------------
#
# ==================== age 12 (n=125) ====================
# [0] speaker=8838, utt_id=K00018838-AFG31-L1N2D1-I-K0KK-04451919
# REF: 아가씨들은 이자벨을 언덕 위에 있는 굴로 안내했는데, 그 굴은 마치 궁전 같았습니다.
# HYP: 아가씨들은 이더블을 언덕 위에 있는 굴로 앉아 있는데, 그 굴은 마주 공장 같았습니다.
# --------------------------------------------------
# [1] speaker=8838, utt_id=K00038838-AFG31-L1N2D1-I-K0KK-04451923
# REF: 뜨레조르까는 그의 주인이 빠른 동작으로 움직이는 이유를 알지 못했다.
# HYP: 트레조룩가는 그의 주인이 빠른 동작으로 움직이는 이유를 알지 못했다.
# --------------------------------------------------
# [2] speaker=8838, utt_id=K00048838-AFG31-L1N2D1-E-K0KK-04451924
# REF: 아이들은 의사의 말을 듣고 어떻게 하면 부모님을 도울 수 있을까 의논을 했습니다.
# HYP: 아이들은 의사의 말을 듣고 어떻게 하면 부모님을 도울 수 있을까 의논을 했습니다.
# --------------------------------------------------
# [3] speaker=8838, utt_id=K00058838-AFG31-L1N2D1-E-K0KK-04451926
# REF: 크리스마스 아침이 되면 텔레비전에서는 여왕이 희망적인 메시지를 전하는 모습을 방영해요.
# HYP: 프리스마스 아침이 되면 텔레비전에서는 여왕이 희망적인 메시지를 전하는 모습을 방영해요.
# --------------------------------------------------
# [4] speaker=8838, utt_id=K00108838-AFG31-L1N2D1-E-K0KK-04451934
# REF: 심부름꾼이던 그가 고난과 역경을 극복하고 성공할 수 있었던 이유는 최선을 다했기 때문입니다.
# HYP: 신부름꾼이던 그가 고난과 역병을 극복하고 성공할 수 있었던 이유는 최선을 다했기 때문입니다.
# --------------------------------------------------
# [5] speaker=8838, utt_id=K00128838-AFG31-L1N2D1-E-K0KK-04451938
# REF: 소녀는 하루종일 들통에 묻은 얼룩을 문지르고, 설거지를 하고, 도자기들을 윤나게 닦아야 했습니다.
# HYP: 소년은 하루 종일 들통에 묻은 얼룩을 문지르고 설거지를 하고, 도자기들을 윤나게 닦아야 했습니다.
# --------------------------------------------------
# [6] speaker=8838, utt_id=K00138838-AFG31-L1N2D1-I-K0KK-04451940
# REF: 톨스토이가 울타리에 붙어서 올려다보니 저쪽 모퉁이에서 무엇인가 움직이는 듯했습니다.
# HYP: 토스토이가 물타리에 붙어서 옹글러다 보니 저쪽 모퉁이에서 무엇인가 움직이는 듯했습니다.
# --------------------------------------------------
# [7] speaker=8838, utt_id=K00148838-AFG31-L1N2D1-E-K0KK-04451942
# REF: 이 집 앞에 커다란 호수를 만들고 세상에서 제일 큰 전함을 몇 척 띄워 놓았으면 좋겠어.
# HYP: 이 집 앞에 커다란 호수를 만들고 세상에서 제일 큰 전함을 며칠 뀌어 놓았으면 좋겠어.
# --------------------------------------------------
# [8] speaker=8838, utt_id=K00168838-AFG31-L1N2D1-E-K0KK-04451945
# REF: 많은 사람들이 있었는데 어떤 이는 뚜렷하게 보이고 또 어떤 이는 희미하게 보였지.
# HYP: 많은 사람들이 있었는데 어떤인은 뚜렷하게 보이고 또 어떤인은 희미하게 보였지.
# --------------------------------------------------
# [9] speaker=8838, utt_id=K00198838-AFG31-L1N2D1-E-K0KK-04451950
# REF: 창이 활짝 열리더니 장밋빛 옷을 입은 아가씨들이 들어왔습니다.
# HYP: 창이 활짝 열리더니 장밋빛 옷을 입은 아가씨들이 들어왔습니다.
# --------------------------------------------------
# [10] speaker=8838, utt_id=K00208838-AFG31-L1N2D1-E-K0KK-04451951
# REF: 이놈의 앞에서는 그것의 이름을 말하지 않도록 주의해야 한다.
# HYP: 이놈의 앞에서는 그것의 이름을 말하지 않도록 주의해야 한다.
# --------------------------------------------------
# [11] speaker=8838, utt_id=K00228838-AFG31-L1N2D1-E-K0KK-04451955
# REF: 뱃사공들은 몇 척의 배에 나누어 타서 호수의 이곳저곳을 돌아다녔습니다.
# HYP: 베사공들은 뇌척에 대해 나누어 타서 호수의 이곳조곳을 돌아다녔습니다.
# --------------------------------------------------
# [12] speaker=8838, utt_id=K00248838-AFG31-L1N2D1-E-K0KK-04451958
# REF: 시인은 사람들이 자기를 조롱한다고 생각해 인간적인 모습을 전혀 보여주지 않았다.
# HYP: 시인은 사람들이 자기를 조롱한다고 생각해 인간적인 모습을 전혀 보여주지 않았다.
# --------------------------------------------------
# [13] speaker=8838, utt_id=K00258838-AFG31-L1N2D1-E-K0KK-04451959
# REF: 소녀가 거위 떼를 몰고 문을 통과하려 할 때, 공주가 문 아래로 지나가면서 말했다.
# HYP: 소녀가 거위뜨를 몰고 문을 통과하려 할 때 공주가 문 아래로 지나가면서 말했다.
# --------------------------------------------------
# [14] speaker=8838, utt_id=K00288838-AFG31-L1N2D1-E-K0KK-04451962
# REF: 무대 위에서의 주인공 역할은 언제나 그녀의 몫이었습니다.
# HYP: 무대 위에서의 주인공 역할은 언제나 그녀의 몫이었습니다.
# --------------------------------------------------
# [15] speaker=8838, utt_id=K00308838-AFG31-L1N2D1-E-K0KK-04451964
# REF: 그런데 교회 문이 잠겨 있어서 안으로 들어가지 못하고, 교회 뒤쪽에 앉아서 바람을 피했습니다.
# HYP: 그런데 교회 문이 잠겨 있어서 안으로 들어가지 못하고 교회 뒤쪽에 앉아서 바람을 피했습니다.
# --------------------------------------------------
# [16] speaker=8838, utt_id=K00328838-AFG31-L1N2D1-E-K0KK-04451966
# REF: 하루도 쉬지 않고 쌓아 올린 성은 거의 완성돼 가고 있었습니다.
# HYP: 하루도 쉬지 않고 쌓아 올린 성은 거의 완성되어가고 있었습니다.
# --------------------------------------------------
# [17] speaker=8838, utt_id=K00358838-AFG31-L1N2D1-E-K0KK-04451969
# REF: 의약품 가방을 든 간호병도 있었고 배낭에 응급용 칼을 챙긴 연락병도 있었다.
# HYP: 위약품 가방을 든 간호병도 있었고, 배당이 응급용 칼을 챙긴 연락병도 있었다.
# --------------------------------------------------
# [18] speaker=8838, utt_id=K00378838-AFG31-L1N2D1-E-K0KK-04451971
# REF: 동물을 놀리는 것은 좋지 못한 일이야.
# HYP: 동물을 울리는 것은 좋지 못한 일이야.
# --------------------------------------------------
# [19] speaker=8838, utt_id=K00388838-AFG31-L1N2D1-E-K0KK-04451972
# REF: 부족한 것이 많은 저에게 이 두 줄의 좌우명은 다시 일어설 수 있는 힘이 되어 주고 있답니다.
# HYP: 부족한 것이 많은 저에게 이 두 줄의 좌우명은 다시 일어설 수 있는 힘이 되어 주고 있답니다.
# --------------------------------------------------
#
# ✅ 나이별 WER/CER:
#    age       wer       cer  n_samples
# 0    4  0.888158  0.695980        125
# 1    5  0.724771  0.619476        125
# 2    6  0.362229  0.159054        125
# 3    7  0.309668  0.215694        125
# 4    8  0.182857  0.062409        125
# 5    9  0.433213  0.371901        125
# 6   10  0.463121  0.213355        125
# 7   11  0.213466  0.069934        125
# 8   12  0.143987  0.046891        125
